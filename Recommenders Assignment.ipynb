# %%
import pandas as pd
import numpy as np

# %%
M = pd.read_csv("Movie_Reviews.csv", index_col = 'Name')

# %%
M
# Out:
#                      American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Aarti Jaiswal                    4.0                                    NaN
# Aditya Dharmasagar               5.0                                    NaN
# Adrian Cavallaris                NaN                                    4.0
# Ahmed Muheebuddin                5.0                                    NaN
# Aishwarya reddy                  NaN                                    3.0
# Akhilesh                         NaN                                    NaN
# Andrew Webb                      4.0                                    3.0
# Anirudh                          3.0                                    4.0
# Anirudh Thota                    NaN                                    3.0
# anurag                           4.0                                    NaN
# Anusha Putta                     NaN                                    NaN
# Arun Vedere                      4.0                                    3.0
# Ashutosh Sureka                  5.0                                    4.0
# Aswini kumar                     4.0                                    4.0
# azam                             4.0                                    NaN
# Benjamin Baysinger               5.0                                    4.0
# Bhuvana Posina                   5.0                                    4.0
# Bradley Brubaker                 NaN                                    1.0
# Brant Mullinix                   NaN                                    4.0
# Charlie                          NaN                                    2.0
# David Huang                      5.0                                    NaN
# David Reyling                    NaN                                    1.0
# Evan Piercy                      4.0                                    NaN
# Graham Bullard                   3.0                                    2.0
# Greg Werner                      5.0                                    3.0
# Harish Kallianpur                5.0                                    3.0
# Heather Sanders                  NaN                                    3.0
# HJ SONG                          NaN                                    2.0
# J A Barnes                       NaN                                    3.0
# Jake Metzger                     NaN                                    NaN
# ...                              ...                                    ...
# Chaitanya Varma                  4.0                                    1.0
# Evan Thompson                    NaN                                    3.0
# Jayesh Fulzele                   4.5                                    3.0
# Aman Chandrakar                  4.0                                    3.5
# Kalyan Chand                     4.0                                    4.0
# Somya Gupta                      NaN                                    3.5
# Gaurav Khandave                  4.0                                    4.0
# Ali Touseef                      4.0                                    3.5
# Gaurav Karale                    5.0                                    4.0
# Aditi Lele                       NaN                                    3.0
# Ugo Obialo                       5.0                                    NaN
# Rohit Ukirde                     5.0                                    4.0
# Megha Sogani                     5.0                                    NaN
# Craig Gordon                     NaN                                    NaN
# Daniel Lee                       NaN                                    4.0
# Trisha Moyer                     4.0                                    5.0
# Vikram Reddy                     NaN                                    3.0
# Camron  Khan                     4.0                                    4.0
# Prachi Jain                      NaN                                    3.0
# Randy Moyers                     4.0                                    4.0
# Sailokesh                        5.0                                    4.0
# Jemberie A                       5.0                                    2.0
# Anupom Syam                      NaN                                    NaN
# Supehr Zangeneh                  4.0                                    4.0
# Karan Deepak Kanwar              5.0                                    NaN
# Mark Dang                        NaN                                    NaN
# Jensen Hou                       5.0                                    3.0
# Moses Stanley                    5.0                                    NaN
# Vibhor Sharma                    5.0                                    3.0
# Jeremy Embalabala                5.0                                    4.0
#
#                      Guardians of the Galaxy  The Lego Movie  The Hobbit  \
# Name
# Aarti Jaiswal                            NaN             NaN         4.0
# Aditya Dharmasagar                       NaN             4.0         5.0
# Adrian Cavallaris                        3.0             NaN         4.0
# Ahmed Muheebuddin                        4.0             NaN         3.0
# Aishwarya reddy                          4.0             3.0         4.0
# Akhilesh                                 4.0             3.0         5.0
# Andrew Webb                              4.0             3.0         3.0
# Anirudh                                  5.0             3.0         5.0
# Anirudh Thota                            4.0             3.0         3.0
# anurag                                   NaN             NaN         3.0
# Anusha Putta                             NaN             NaN         4.0
# Arun Vedere                              4.0             3.0         5.0
# Ashutosh Sureka                          5.0             5.0         5.0
# Aswini kumar                             5.0             NaN         NaN
# azam                                     3.0             NaN         5.0
# Benjamin Baysinger                       5.0             5.0         3.0
# Bhuvana Posina                           4.0             5.0         3.0
# Bradley Brubaker                         5.0             5.0         5.0
# Brant Mullinix                           4.0             4.0         5.0
# Charlie                                  3.0             NaN         3.0
# David Huang                              4.0             NaN         NaN
# David Reyling                            NaN             NaN         1.0
# Evan Piercy                              NaN             4.0         NaN
# Graham Bullard                           4.0             3.0         4.0
# Greg Werner                              3.0             NaN         NaN
# Harish Kallianpur                        NaN             NaN         5.0
# Heather Sanders                          NaN             1.0         3.0
# HJ SONG                                  3.0             4.0         4.0
# J A Barnes                               4.0             NaN         4.0
# Jake Metzger                             4.0             NaN         NaN
# ...                                      ...             ...         ...
# Chaitanya Varma                          4.0             4.0         5.0
# Evan Thompson                            4.0             4.0         4.0
# Jayesh Fulzele                           4.5             4.0         3.0
# Aman Chandrakar                          NaN             4.0         4.0
# Kalyan Chand                             3.0             NaN         5.0
# Somya Gupta                              NaN             NaN         4.0
# Gaurav Khandave                          4.5             3.0         3.5
# Ali Touseef                              4.0             NaN         4.5
# Gaurav Karale                            4.0             3.0         4.0
# Aditi Lele                               5.0             5.0         5.0
# Ugo Obialo                               3.0             NaN         4.0
# Rohit Ukirde                             5.0             5.0         5.0
# Megha Sogani                             3.0             NaN         5.0
# Craig Gordon                             3.0             1.0         3.0
# Daniel Lee                               4.0             NaN         3.0
# Trisha Moyer                             NaN             5.0         NaN
# Vikram Reddy                             4.0             NaN         4.0
# Camron  Khan                             3.0             2.0         3.0
# Prachi Jain                              NaN             NaN         4.0
# Randy Moyers                             5.0             NaN         4.0
# Sailokesh                                4.0             3.0         5.0
# Jemberie A                               2.0             2.0         2.0
# Anupom Syam                              3.0             NaN         3.0
# Supehr Zangeneh                          NaN             NaN         NaN
# Karan Deepak Kanwar                      4.0             5.0         4.0
# Mark Dang                                4.0             NaN         2.0
# Jensen Hou                               3.0             5.0         3.0
# Moses Stanley                            3.0             NaN         3.0
# Vibhor Sharma                            4.0             NaN         4.0
# Jeremy Embalabala                        NaN             NaN         3.0
#
#                      Transformers  Malificent  Big Hero 6  Godzilla  \
# Name
# Aarti Jaiswal                 3.0         NaN         5.0       NaN
# Aditya Dharmasagar            4.0         4.0         NaN       4.0
# Adrian Cavallaris             2.0         NaN         NaN       NaN
# Ahmed Muheebuddin             NaN         NaN         NaN       NaN
# Aishwarya reddy               4.0         3.0         NaN       4.0
# Akhilesh                      4.0         NaN         NaN       NaN
# Andrew Webb                   2.0         NaN         4.0       3.0
# Anirudh                       3.0         5.0         NaN       4.0
# Anirudh Thota                 4.0         NaN         NaN       3.0
# anurag                        NaN         NaN         NaN       5.0
# Anusha Putta                  4.0         NaN         NaN       3.0
# Arun Vedere                   5.0         3.0         NaN       3.0
# Ashutosh Sureka               5.0         0.0         5.0       2.0
# Aswini kumar                  NaN         NaN         5.0       3.0
# azam                          NaN         NaN         NaN       NaN
# Benjamin Baysinger            2.0         2.0         4.0       4.0
# Bhuvana Posina                5.0         3.0         3.0       4.0
# Bradley Brubaker              4.0         NaN         NaN       4.0
# Brant Mullinix                3.0         NaN         NaN       NaN
# Charlie                       2.0         3.0         NaN       4.0
# David Huang                   5.0         NaN         NaN       4.0
# David Reyling                 1.0         NaN         NaN       3.0
# Evan Piercy                   4.0         NaN         NaN       NaN
# Graham Bullard                NaN         3.0         4.0       3.0
# Greg Werner                   4.0         4.0         NaN       NaN
# Harish Kallianpur             4.0         4.0         NaN       4.0
# Heather Sanders               3.0         3.0         4.0       NaN
# HJ SONG                       5.0         NaN         4.0       4.0
# J A Barnes                    4.0         NaN         NaN       NaN
# Jake Metzger                  2.0         3.0         NaN       2.0
# ...                           ...         ...         ...       ...
# Chaitanya Varma               4.0         3.5         4.0       3.0
# Evan Thompson                 2.0         NaN         5.0       NaN
# Jayesh Fulzele                2.0         2.0         3.0       4.0
# Aman Chandrakar               4.0         3.0         5.0       3.5
# Kalyan Chand                  5.0         3.0         5.0       4.0
# Somya Gupta                   5.0         NaN         5.0       3.5
# Gaurav Khandave               3.0         3.0         4.5       4.0
# Ali Touseef                   5.0         3.5         NaN       2.0
# Gaurav Karale                 4.0         3.0         3.0       4.0
# Aditi Lele                    3.0         4.0         1.0       5.0
# Ugo Obialo                    3.0         NaN         NaN       NaN
# Rohit Ukirde                  3.0         3.0         2.0       1.0
# Megha Sogani                  4.0         NaN         1.0       5.0
# Craig Gordon                  3.0         NaN         3.0       NaN
# Daniel Lee                    3.0         2.0         NaN       NaN
# Trisha Moyer                  2.0         NaN         5.0       NaN
# Vikram Reddy                  3.0         3.0         4.0       3.0
# Camron  Khan                  NaN         NaN         NaN       3.0
# Prachi Jain                   2.5         NaN         2.0       3.0
# Randy Moyers                  3.0         NaN         NaN       3.0
# Sailokesh                     4.0         NaN         NaN       4.0
# Jemberie A                    3.0         NaN         NaN       2.0
# Anupom Syam                   3.0         NaN         5.0       3.0
# Supehr Zangeneh               NaN         NaN         NaN       NaN
# Karan Deepak Kanwar           5.0         NaN         NaN       5.0
# Mark Dang                     2.0         3.0         5.0       NaN
# Jensen Hou                    2.0         NaN         5.0       3.0
# Moses Stanley                 4.0         NaN         NaN       4.0
# Vibhor Sharma                 3.0         3.0         4.0       3.0
# Jeremy Embalabala             3.0         NaN         NaN       NaN
#
#                      Interstellar  How to Train your Dragon 2  Gone Girl  \
# Name
# Aarti Jaiswal                 NaN                         NaN        4.0
# Aditya Dharmasagar            5.0                         5.0        5.0
# Adrian Cavallaris             NaN                         NaN        NaN
# Ahmed Muheebuddin             NaN                         NaN        NaN
# Aishwarya reddy               4.0                         3.0        5.0
# Akhilesh                      5.0                         NaN        3.0
# Andrew Webb                   4.0                         3.0        4.0
# Anirudh                       NaN                         NaN        2.0
# Anirudh Thota                 4.0                         3.0        NaN
# anurag                        NaN                         3.0        NaN
# Anusha Putta                  NaN                         NaN        5.0
# Arun Vedere                   5.0                         4.0        NaN
# Ashutosh Sureka               3.0                         5.0        3.0
# Aswini kumar                  5.0                         4.0        NaN
# azam                          NaN                         NaN        NaN
# Benjamin Baysinger            4.0                         4.0        5.0
# Bhuvana Posina                5.0                         3.0        5.0
# Bradley Brubaker              NaN                         4.0        NaN
# Brant Mullinix                5.0                         3.0        3.0
# Charlie                       5.0                         2.0        NaN
# David Huang                   5.0                         NaN        NaN
# David Reyling                 NaN                         NaN        NaN
# Evan Piercy                   5.0                         NaN        2.0
# Graham Bullard                4.0                         NaN        4.0
# Greg Werner                   5.0                         4.0        5.0
# Harish Kallianpur             5.0                         4.0        NaN
# Heather Sanders               NaN                         3.0        NaN
# HJ SONG                       5.0                         5.0        NaN
# J A Barnes                    NaN                         3.0        NaN
# Jake Metzger                  NaN                         NaN        5.0
# ...                           ...                         ...        ...
# Chaitanya Varma               5.0                         4.0        5.0
# Evan Thompson                 NaN                         4.0        NaN
# Jayesh Fulzele                5.0                         4.0        5.0
# Aman Chandrakar               4.5                         5.0        5.0
# Kalyan Chand                  5.0                         5.0        5.0
# Somya Gupta                   5.0                         4.0        NaN
# Gaurav Khandave               5.0                         4.5        5.0
# Ali Touseef                   5.0                         4.0        NaN
# Gaurav Karale                 5.0                         4.0        4.0
# Aditi Lele                    5.0                         5.0        5.0
# Ugo Obialo                    5.0                         4.0        NaN
# Rohit Ukirde                  5.0                         3.0        3.0
# Megha Sogani                  4.0                         2.0        4.0
# Craig Gordon                  2.0                         4.0        NaN
# Daniel Lee                    4.0                         NaN        5.0
# Trisha Moyer                  NaN                         4.0        NaN
# Vikram Reddy                  5.0                         4.0        4.0
# Camron  Khan                  4.0                         NaN        4.0
# Prachi Jain                   5.0                         4.0        4.0
# Randy Moyers                  4.0                         3.0        NaN
# Sailokesh                     5.0                         3.0        NaN
# Jemberie A                    NaN                         NaN        NaN
# Anupom Syam                   4.0                         4.0        4.0
# Supehr Zangeneh               NaN                         NaN        NaN
# Karan Deepak Kanwar           4.0                         3.0        4.0
# Mark Dang                     5.0                         NaN        NaN
# Jensen Hou                    5.0                         4.0        4.0
# Moses Stanley                 5.0                         NaN        NaN
# Vibhor Sharma                 5.0                         3.0        5.0
# Jeremy Embalabala             NaN                         NaN        NaN
#
#                      Divergent  The Fault in Our Stars  Unbroken  \
# Name
# Aarti Jaiswal              NaN                     NaN       NaN
# Aditya Dharmasagar         4.0                     4.0       NaN
# Adrian Cavallaris          4.0                     NaN       NaN
# Ahmed Muheebuddin          NaN                     NaN       NaN
# Aishwarya reddy            NaN                     4.0       NaN
# Akhilesh                   NaN                     NaN       NaN
# Andrew Webb                2.0                     3.0       NaN
# Anirudh                    3.0                     4.0       NaN
# Anirudh Thota              NaN                     NaN       NaN
# anurag                     3.0                     NaN       NaN
# Anusha Putta               4.0                     NaN       NaN
# Arun Vedere                NaN                     NaN       NaN
# Ashutosh Sureka            3.0                     2.0       2.0
# Aswini kumar               NaN                     NaN       NaN
# azam                       NaN                     NaN       NaN
# Benjamin Baysinger         1.0                     4.0       3.0
# Bhuvana Posina             3.0                     3.0       3.0
# Bradley Brubaker           3.0                     NaN       NaN
# Brant Mullinix             NaN                     NaN       NaN
# Charlie                    2.0                     3.0       NaN
# David Huang                NaN                     NaN       NaN
# David Reyling              NaN                     NaN       NaN
# Evan Piercy                NaN                     NaN       NaN
# Graham Bullard             NaN                     NaN       4.0
# Greg Werner                4.0                     NaN       NaN
# Harish Kallianpur          3.0                     NaN       NaN
# Heather Sanders            3.0                     3.0       5.0
# HJ SONG                    NaN                     NaN       5.0
# J A Barnes                 3.0                     NaN       NaN
# Jake Metzger               NaN                     NaN       NaN
# ...                        ...                     ...       ...
# Chaitanya Varma            4.0                     4.0       3.0
# Evan Thompson              4.0                     NaN       NaN
# Jayesh Fulzele             3.0                     NaN       3.0
# Aman Chandrakar            3.5                     3.0       NaN
# Kalyan Chand               3.0                     NaN       NaN
# Somya Gupta                NaN                     NaN       4.0
# Gaurav Khandave            NaN                     NaN       5.0
# Ali Touseef                5.0                     NaN       3.5
# Gaurav Karale              4.0                     5.0       5.0
# Aditi Lele                 NaN                     4.0       NaN
# Ugo Obialo                 NaN                     NaN       NaN
# Rohit Ukirde               2.0                     5.0       3.0
# Megha Sogani               3.0                     1.0       4.0
# Craig Gordon               NaN                     NaN       NaN
# Daniel Lee                 3.0                     NaN       NaN
# Trisha Moyer               NaN                     NaN       NaN
# Vikram Reddy               NaN                     4.0       NaN
# Camron  Khan               NaN                     NaN       4.0
# Prachi Jain                3.0                     5.0       NaN
# Randy Moyers               4.0                     NaN       NaN
# Sailokesh                  NaN                     4.0       NaN
# Jemberie A                 NaN                     NaN       NaN
# Anupom Syam                NaN                     NaN       NaN
# Supehr Zangeneh            NaN                     NaN       NaN
# Karan Deepak Kanwar        NaN                     5.0       NaN
# Mark Dang                  NaN                     NaN       NaN
# Jensen Hou                 4.0                     NaN       NaN
# Moses Stanley              NaN                     NaN       NaN
# Vibhor Sharma              4.0                     3.0       4.0
# Jeremy Embalabala          NaN                     NaN       NaN
#
#                      300: Rise of an Empire
# Name
# Aarti Jaiswal                           NaN
# Aditya Dharmasagar                      5.0
# Adrian Cavallaris                       NaN
# Ahmed Muheebuddin                       NaN
# Aishwarya reddy                         3.0
# Akhilesh                                5.0
# Andrew Webb                             3.0
# Anirudh                                 2.0
# Anirudh Thota                           4.0
# anurag                                  5.0
# Anusha Putta                            NaN
# Arun Vedere                             1.0
# Ashutosh Sureka                         4.0
# Aswini kumar                            4.0
# azam                                    NaN
# Benjamin Baysinger                      2.0
# Bhuvana Posina                          5.0
# Bradley Brubaker                        2.0
# Brant Mullinix                          4.0
# Charlie                                 2.0
# David Huang                             5.0
# David Reyling                           NaN
# Evan Piercy                             2.0
# Graham Bullard                          3.0
# Greg Werner                             4.0
# Harish Kallianpur                       3.0
# Heather Sanders                         NaN
# HJ SONG                                 5.0
# J A Barnes                              NaN
# Jake Metzger                            3.0
# ...                                     ...
# Chaitanya Varma                         4.0
# Evan Thompson                           NaN
# Jayesh Fulzele                          2.0
# Aman Chandrakar                         3.0
# Kalyan Chand                            3.0
# Somya Gupta                             4.0
# Gaurav Khandave                         4.5
# Ali Touseef                             5.0
# Gaurav Karale                           5.0
# Aditi Lele                              NaN
# Ugo Obialo                              NaN
# Rohit Ukirde                            2.0
# Megha Sogani                            NaN
# Craig Gordon                            4.0
# Daniel Lee                              5.0
# Trisha Moyer                            NaN
# Vikram Reddy                            2.0
# Camron  Khan                            NaN
# Prachi Jain                             4.0
# Randy Moyers                            3.0
# Sailokesh                               3.0
# Jemberie A                              NaN
# Anupom Syam                             5.0
# Supehr Zangeneh                         4.0
# Karan Deepak Kanwar                     4.0
# Mark Dang                               3.0
# Jensen Hou                              NaN
# Moses Stanley                           4.0
# Vibhor Sharma                           5.0
# Jeremy Embalabala                       4.0
#
# [124 rows x 16 columns]

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %% [markdown]
# **Question 1: What movie is most Similar to 'The fault in our stars'**

# %%
get_recs('The Fault in Our Stars', M, 1)
# Out:
# [('Malificent', 0.20279670863265634)]

# %% [markdown]
# **Question 2:  Which movie(s) would you most like to see, based on your classmates experience?**

# %%
#the movies I've seen
my_ratings = M.ix['Prachi Jain'].dropna()

#the movie that i have given highest rating
my_ratings.sort(ascending=False)
fav_movie = my_ratings.index[0]
# Out:
# C:\Users\prach\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %%
fav_movie
# Out:
# 'The Fault in Our Stars'

# %%
get_recs(fav_movie, M, 1)
# Out:
# [('Malificent', 0.20279670863265634)]

# %% [markdown]
# **Question 3:For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews?**

# %%
notviewed = M.ix['Prachi Jain']
notviewed.sort()
for i in range(0, notviewed.count(), 1):
    notviewed.drop(notviewed.index[0], inplace=True)
# Out:
# C:\Users\prach\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   from ipykernel import kernelapp as app

# %%
notviewed
# Out:
# American Sniper           NaN
# Guardians of the Galaxy   NaN
# The Lego Movie            NaN
# Malificent                NaN
# Unbroken                  NaN
# Name: Prachi Jain, dtype: float64

# %%
print ("Pearson Correlation coefficient of :")
a= []
for i in range(0, M.shape[0], 1): 
    cor=pearson(M.ix[112], M.ix[i])
    print ("(" + M.index[112] + " , " + M.index[i] + ") :", cor)
    a.append(cor)
# Out:
# Pearson Correlation coefficient of :
# (Prachi Jain , Aarti Jaiswal) : -0.115260679135
# (Prachi Jain , Aditya Dharmasagar) : 0.367884351677
# (Prachi Jain , Adrian Cavallaris) : 0.193840425794
# (Prachi Jain , Ahmed Muheebuddin) : -0.0943041920193
# (Prachi Jain , Aishwarya reddy) : 0.137192412152
# (Prachi Jain , Akhilesh) : 0.236292596973
# (Prachi Jain , Andrew Webb) : 0.246843554631
# (Prachi Jain , Anirudh) : 0.0326415384842
# (Prachi Jain , Anirudh Thota) : 0.123704431276
# (Prachi Jain , anurag) : -0.0595394381848
# (Prachi Jain , Anusha Putta) : 0.230521358269
# (Prachi Jain , Arun Vedere) : 0.0695846390998
# (Prachi Jain , Ashutosh Sureka) : -0.257750076641
# (Prachi Jain , Aswini kumar) : 0.0950496913044
# (Prachi Jain , azam) : 0.0943041920193
# (Prachi Jain , Benjamin Baysinger) : 0.208984069547
# (Prachi Jain , Bhuvana Posina) : 0.0988756945417
# (Prachi Jain , Bradley Brubaker) : 0.114843174656
# (Prachi Jain , Brant Mullinix) : 0.330627416832
# (Prachi Jain , Charlie) : 0.409228530734
# (Prachi Jain , David Huang) : 0.179664450819
# (Prachi Jain , David Reyling) : -0.0470549752144
# (Prachi Jain , Evan Piercy) : 0.0405820627965
# (Prachi Jain , Graham Bullard) : 0.188793290638
# (Prachi Jain , Greg Werner) : 0.349442681922
# (Prachi Jain , Harish Kallianpur) : 0.344828154104
# (Prachi Jain , Heather Sanders) : -0.155968943954
# (Prachi Jain , HJ SONG) : 0.266888172218
# (Prachi Jain , J A Barnes) : 0.0120992334773
# (Prachi Jain , Jake Metzger) : 0.329732200018
# (Prachi Jain , James Goodpasture) : 0.107467389519
# (Prachi Jain , Jared Knowles) : -0.0486984753558
# (Prachi Jain , Jessica Fong) : 0.346300269197
# (Prachi Jain , Jonathan Doll) : 0.210766424572
# (Prachi Jain , Josna Rajan) : 0.208570822665
# (Prachi Jain , krishna sai) : -0.295628568654
# (Prachi Jain , M A Nissar) : -0.187440519039
# (Prachi Jain , Maheshwar Reddy) : 0.511687560401
# (Prachi Jain , Manideep Maddipatla) : 0.235061256664
# (Prachi Jain , Melanie Klein) : -0.176930723475
# (Prachi Jain , Michael Cooper) : 0.251477845385
# (Prachi Jain , Mike) : -0.0129966615864
# (Prachi Jain , Olumuyiwa Durojaiye) : -0.451420777475
# (Prachi Jain , Onsiri Tapsarn) : nan
# (Prachi Jain , Pavithra Shetty) : 0.0245736593591
# (Prachi Jain , Rajesh Kinkirla) : -0.200974367172
# (Prachi Jain , Ryan Hansen) : 0.470383058007
# (Prachi Jain , Jordan Hoover) : 0.261037931234
# (Prachi Jain , sai bhargav musuluri) : -0.0497026732805
# (Prachi Jain , Sai Sampath) : 0.137192412152
# (Prachi Jain , Sai Yallapragada) : 0.455668080086
# (Prachi Jain , saikiran reddy) : 0.147127938687
# (Prachi Jain , sandeep katragadda) : -0.0938707605236
# (Prachi Jain , Sara Collins) : -0.0786450176027
# (Prachi Jain , Shannon Morrison) : 0.017110900078
# (Prachi Jain , Shiva rama raju Chekuri) : 0.101892827167
# (Prachi Jain , siddanth sudarshan) : 0.091650492348
# (Prachi Jain , Sina Tuy) : -0.0915348653085
# (Prachi Jain , Sohaib Ahmed) : 0.221162934232
# (Prachi Jain , solomon choppara) : -0.0470549752144
# (Prachi Jain , Sundar Prasad) : -0.266183136502
# (Prachi Jain , Sunil Nandikanti) : 0.0713091263306
# (Prachi Jain , surya chandra reddy kovvuri) : 0.0410710209506
# (Prachi Jain , Susan Huang) : 0.241268655526
# (Prachi Jain , Suyendra) : 0.51926624925
# (Prachi Jain , Syed Abbas Hussaini) : -0.00624801730128
# (Prachi Jain , Syed Farzan) : 0.467582656193
# (Prachi Jain , Thomas Podlipni) : 0.386421160094
# (Prachi Jain , Trudy Kline) : -0.261876549685
# (Prachi Jain , Tyler Vitanova) : 0.390968591344
# (Prachi Jain , ugesh reddy challa) : 0.307154474794
# (Prachi Jain , veerendra battula) : 0.152335532429
# (Prachi Jain , Venkatesh Komma) : 0.615079314483
# (Prachi Jain , Violeta Lee Fay) : -0.392124793454
# (Prachi Jain , Yinka Adeyemo) : nan
# (Prachi Jain , Sai Sharan Vellala) : -0.25195960099
# (Prachi Jain , Andrew Peabody) : -0.141254402355
# (Prachi Jain , Matthew Dearing) : -0.302634055086
# (Prachi Jain , Matthew Murphy) : -0.201242203242
# (Prachi Jain , Fred Young) : 0.264251979368
# (Prachi Jain , Rohit Tatar) : 0.0915556662241
# (Prachi Jain , Pratik Belhekar) : 0.244832276642
# (Prachi Jain , Chris DiBello) : 0.389141043806
# (Prachi Jain , Rajat Hatwar) : 0.393257019707
# (Prachi Jain , Chaitanya Kusurkar) : 0.0446690142705
# (Prachi Jain , Ramya Doddi) : -0.113030885847
# (Prachi Jain , Amy Camp) : 0.42412947866
# (Prachi Jain , Poojitha Polusani) : 0.543577505212
# (Prachi Jain , Tushar Borole) : 0.454543258668
# (Prachi Jain , Roopa Maddikunta) : -0.316582737146
# (Prachi Jain , Josh Garrett) : -0.119764433869
# (Prachi Jain , Koushal Yeginwar) : 0.470751928439
# (Prachi Jain , Rajesh Jaiswal) : -0.107536450034
# (Prachi Jain , Shreya Kulkarni) : 0.297331935235
# (Prachi Jain , Chaitanya Varma) : 0.402024978812
# (Prachi Jain , Evan Thompson) : 0.0584472221221
# (Prachi Jain , Jayesh Fulzele) : 0.400425046139
# (Prachi Jain , Aman Chandrakar) : -0.123852369106
# (Prachi Jain , Kalyan Chand) : 0.0369800855846
# (Prachi Jain , Somya Gupta) : -0.0762958479469
# (Prachi Jain , Gaurav Khandave) : 0.294572648351
# (Prachi Jain , Ali Touseef) : 0.200568494023
# (Prachi Jain , Gaurav Karale) : 0.564233023328
# (Prachi Jain , Aditi Lele) : 0.656926426184
# (Prachi Jain , Ugo Obialo) : 0.407508039102
# (Prachi Jain , Rohit Ukirde) : 0.543283106941
# (Prachi Jain , Megha Sogani) : 0.0165092175662
# (Prachi Jain , Craig Gordon) : -0.0741765188373
# (Prachi Jain , Daniel Lee) : 0.254970593237
# (Prachi Jain , Trisha Moyer) : 0.0595218584559
# (Prachi Jain , Vikram Reddy) : 0.385493424709
# (Prachi Jain , Camron  Khan) : 0.120994988085
# (Prachi Jain , Prachi Jain) : 1.0
# (Prachi Jain , Randy Moyers) : 0.128070648075
# (Prachi Jain , Sailokesh) : 0.133091568251
# (Prachi Jain , Jemberie A) : -0.00304872027005
# (Prachi Jain , Anupom Syam) : 0.00558839656411
# (Prachi Jain , Supehr Zangeneh) : nan
# (Prachi Jain , Karan Deepak Kanwar) : -0.258431501059
# (Prachi Jain , Mark Dang) : 0.0536570882741
# (Prachi Jain , Jensen Hou) : 0.235720005051
# (Prachi Jain , Moses Stanley) : 0.163003215641
# (Prachi Jain , Vibhor Sharma) : 0.280236499932
# (Prachi Jain , Jeremy Embalabala) : 0.0991841997986
# C:\Users\prach\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: invalid value encountered in double_scalars

# %%
def pred_rate(x, a):
    """
    Takes two parameters 'x' and 'a'. 
    Where 'x' a list of rates given by classmates. 
    'a' is a array that has corresponding pearson correlation coefficientreturn (weights for the given rates).
    predicted rate is calculated as rate= (x[0]*a[0] + x[1]*a[1] +...+x[i]*a[i]) / (a[0]+a[1]+..+a[i]) 
    returns predicted rate 
    """
    j=0
    k=0
    for i in range(0, 23, 1): # as there are 23 rows(x.shape), range(0,23) 
        if x.irow(i)>0 and a[i]>0: 
            j= j+(a[i]*x.irow(i))
            k= k+a[i]
        else:
            continue
    return j/k

# %%
print ("Based on class ratings, the rating for the unwatched movie will be: ")
for i in range(0, notviewed.shape[0], 1):
    x=M[notviewed.index[i]]
    rate=pred_rate(x, a)
    print (notviewed.index[i] +": ", rate.round(1))
# Out:
# Based on class ratings, the rating for the unwatched movie will be:
# American Sniper:  4.0
# Guardians of the Galaxy:  4.0
# The Lego Movie:  3.4
# Malificent:  3.4
# Unbroken:  3.0
# C:\Users\prach\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: irow(i) is deprecated. Please use .iloc[i] or .iat[i]
# C:\Users\prach\Anaconda3\lib\site-packages\ipykernel\__main__.py:13: FutureWarning: irow(i) is deprecated. Please use .iloc[i] or .iat[i]
